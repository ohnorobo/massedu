# %%
"code available at https://github.com/ohnorobo/massedu"
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
ap_participation = pd.read_csv("./MassEduDataChallenge/assessment/ap_participation_state_district_school_2007_2013.csv", sep='\t')
ap_performance = pd.read_csv("./MassEduDataChallenge/assessment/ap_performance_state_district_school_2007_2013.csv", sep='\t')
sats = pd.read_csv("./MassEduDataChallenge/assessment/sat_performance_report_state_district_school_2005_2013.csv", sep='\t')

# %%
sats[:5]
# Out:
#    REC_YEAR  ORG_CODE  SCHOOL SAT_STU_GROUP_CODE     LABEL_STU SAT_TAKEN  \
# 0      2005     50000   50505                ALL  All Students       206
# 1      2005     70000   70505                ALL  All Students       110
# 2      2005     90000   90505                ALL  All Students       358
# 3      2005    100000  100505                ALL  All Students       229
# 4      2005    140000  140505                ALL  All Students       118
#
#    SAT_READ  SAT_WRITE  SAT_MATH  SORT
# 0       487        NaN       499     1
# 1       545        NaN       529     1
# 2       558        NaN       585     1
# 3       541        NaN       553     1
# 4       551        NaN       565     1
#
# [5 rows x 10 columns]

# %%
ap_performance[:5]
# Out:
#    REC_YEAR  ORG_CODE  SCHOOL AP_STU_GROUP_CODE           LABEL_STU  \
# 0      2007         0     NaN               ALL        All Students
# 1      2007         0     NaN               LEP  Lim. English Prof.
# 2      2007         0     NaN            LOWINC          Low Income
# 3      2007         0     NaN              SPED   Special Education
# 4      2007         0     NaN                 F              Female
#
#   AP_SUBJ_CODE    LABEL_SUBJ  AP_TESTS_TAKEN  AP_SCORE_1  AP_PCT_1  \
# 0          ALL  All Subjects           44357        5153      11.6
# 1          ALL  All Subjects             208          54      26.0
# 2          ALL  All Subjects            4223        1257      29.8
# 3          ALL  All Subjects             374          64      17.1
# 4          ALL  All Subjects           24837        3105      12.5
#
#    AP_SCORE_2  AP_PCT_2  AP_SCORE_3  AP_PCT_3  AP_SCORE_4  AP_PCT_4  \
# 0        7345      16.6       10856      24.5       11045      24.9
# 1          23      11.1          37      17.8          41      19.7
# 2        1026      24.3         941      22.3         579      13.7
# 3          52      13.9          81      21.7          89      23.8
# 4        4544      18.3        6439      25.9        6048      24.4
#
#    AP_SCORE_5  AP_PCT_5  AP_SCORE_1_2  AP_PCT_1_2
# 0        9958      22.4         12498        28.2 ...
# 1          53      25.5            77        37.0 ...
# 2         420       9.9          2283        54.1 ...
# 3          88      23.5           116        31.0 ...
# 4        4701      18.9          7649        30.8 ...
#
# [5 rows x 24 columns]

# %%
boundaries = (42.88679, 41.187053, -69.858861, -73.508142)
north, south, east, west = boundaries
b = Basemap(projection="lcc", 
            llcrnrlon=west,
            llcrnrlat=south,
            urcrnrlon=east,
            urcrnrlat=north,
            lat_0=(south+north)/2,
            lon_0=(east+west)/2)
unified_info = b.readshapefile("./shapefiles/tl_2013_25_unsd/tl_2013_25_unsd", "districts") #unified
unified_districts = b.districts
unified_districts_info = b.districts_info

secondary_info = b.readshapefile("./shapefiles/tl_2013_25_scsd/tl_2013_25_scsd", "districts") #secondary
secondary_districts = b.districts
secondary_districts_info = b.districts_info

districts = unified_districts + secondary_districts
districts_info = unified_districts_info + secondary_districts_info

plt.savefig("state.svg", figsize=(400,200), dpi=1000)
#plt.title("All Districts")

# %%
districts_info[0]
# Out:
# {'ALAND': 428888279,
#  'AWATER': 10412095,
#  'FUNCSTAT': 'E',
#  'GEOID': '2500001',
#  'HIGRADE': '12',
#  'INTPTLAT': '+42.3975002',
#  'INTPTLON': '-072.1036444',
#  'LOGRADE': 'PK',
#  'LSAD': '00',
#  'MTFCC': 'G5420',
#  'NAME': 'Quabbin School District',
#  'RINGNUM': 1,
#  'SDTYP': ' ',
#  'SHAPENUM': 1,
#  'STATEFP': '25',
#  'UNSDLEA': '00001'}

# %%
sorted(map(lambda x: [x['NAME'], x['GEOID']], districts_info))[:10]
# Out:
# [['Abington School District', '2501650'],
#  ['Acton-Boxborough School District', '2501710'],
#  ['Adams-Cheshire School District', '2501780'],
#  ['Adams-Cheshire School District in Savoy (7-12)', '2525008'],
#  ['Agawam School District', '2501800'],
#  ['Amesbury School District', '2501860'],
#  ['Amherst-Pelham School District', '2501920'],
#  ['Andover School District', '2501950'],
#  ['Arlington School District', '2501980'],
#  ['Ashburnham-Westminster School District', '2502040']]

# %%
cols = ['DISTRICT_CODE', 'DIST_NAME', 'SCHOOL_CODE', 'SCHOOL_NAME']
accountability = pd.read_csv("./MassEduDataChallenge/accountability/accountability_school_2007_2011.csv", sep=',', usecols=cols)
accountability[:10]
# Out:
#    DISTRICT_CODE DIST_NAME  SCHOOL_CODE     SCHOOL_NAME
# 0          10000  Abington        10003    Abington ECC
# 1          10000  Abington        10005          Center
# 2          10000  Abington        10010           North
# 3          10000  Abington        10015       Woodsdale
# 4          10000  Abington        10405    Frolio Jr Hs
# 5          10000  Abington        10505   Abington High
# 6          20000     Acton        20010         Merriam
# 7          20000     Acton        20015  McCarthy-Towne
# 8          20000     Acton        20020         Douglas
# 9          20000     Acton        20025           Gates
#
# [10 rows x 4 columns]

# %%
a_districts = accountability["DIST_NAME"].tolist()
a_dist_codes = accountability["DISTRICT_CODE"].tolist()
both = zip(a_districts, a_dist_codes)
sorted(list(set(both)))[:10]
# Out:
# [('Abby Kelley Foster Charter Public (District)', 4450000),
#  ('Abington', 10000),
#  ('Academy Of the Pacific Rim Charter Public (District)', 4120000),
#  ('Academy of Strategic Learning Charter (District)', 4150000),
#  ('Acton', 20000),
#  ('Acton-Boxborough', 6000000),
#  ('Acushnet', 30000),
#  ('Adams-Cheshire', 6030000),
#  ('Advanced Math and Science Academy Charter (District)', 4300000),
#  ('Agawam', 50000)]

# %%
cols = ['ORG_NCES_ID', 'ORG_CODE', 'ORG_NAME', 'DISTRICT_NAME']
ese_to_census = pd.read_csv("./MassEduDataChallenge/ese_orgs_names_mapped_to_census_org_names.csv", sep=',', usecols=cols)
ese_to_census[:10]

# ORG_NCES_ID is the census id code, it matches up to GEOID in the census shapefiles
# DISTRICT_NAME is the census name, it matches up to NAME in the census shapefiles

# ORG_CODE is the ESE code, it matches up to ORG_CODE, DIST_CODE or DISTRICT_CODE in the ESE data
# ORG_NAME is the ESE name, it matches up to DIST_NAME or DISTRICT_NAME in the ESE data
# Out:
#    ORG_NCES_ID  ORG_CODE          ORG_NAME                     DISTRICT_NAME
# 0      2501650     10000          Abington          Abington School District
# 1      2501680     20000             Acton             Acton School District
# 2      2501710   6000000  Acton-Boxborough  Acton-Boxborough School District
# 3      2501740     30000          Acushnet          Acushnet School District
# 4      2501780   6030000    Adams-Cheshire    Adams-Cheshire School District
# 5      2501800     50000            Agawam            Agawam School District
# 6      2501860     70000          Amesbury          Amesbury School District
# 7      2501890     80000           Amherst           Amherst School District
# 8      2501920   6050000    Amherst-Pelham    Amherst-Pelham School District
# 9      2501950     90000           Andover           Andover School District
#
# [10 rows x 4 columns]

# %%
def get_org_code(nces_id):
    #given an nces id return an org code or throw an error
    filtered = ese_to_census[ese_to_census['ORG_NCES_ID'] == nces_id]
    if filtered.shape[0] == 0:
        raise Exception("no such id " + str(nces_id))
    elif filtered.shape[0] > 1:
        print(filtered)
        raise Exception("multiple ids " + str(filtered.count))
    return filtered['ORG_CODE'].values[0]
    
get_org_code(2501710) # Acton-Boxburough, 6000000
# Out:
# 6000000

# %%
import matplotlib.axes as ax
import matplotlib.cm as cm
#dir(cm)

# %%
for border, info in zip(districts, districts_info):
    name = info["NAME"]
    score = len(name)
    color = cm.ScalarMappable(score)
    xx,yy = zip(*border)
    patch = ax.fill(xx, yy, facecolor=color, edgecolor=color)
ax
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3186b2d2329a> in <module>()
#       5     color = cm.ScalarMappable(score)
#       6     xx,yy = zip(*border)
# ----> 7     patch = ax.fill(xx, yy, facecolor=color, edgecolor=color)
#       8 ax
#
# AttributeError: 'module' object has no attribute 'fill'

# %%
cols = ['REC_YEAR', 'ORG_CODE', 'SAT_READ', 'SAT_WRITE', 'SAT_MATH', 'SAT_STU_GROUP_CODE']
sats = pd.read_csv("./MassEduDataChallenge/assessment/sat_performance_report_state_district_school_2005_2013.csv", sep='\t', usecols=cols)
sats[:5]
# Out:
#    REC_YEAR  ORG_CODE SAT_STU_GROUP_CODE  SAT_READ  SAT_WRITE  SAT_MATH
# 0      2005     50000                ALL       487        NaN       499
# 1      2005     70000                ALL       545        NaN       529
# 2      2005     90000                ALL       558        NaN       585
# 3      2005    100000                ALL       541        NaN       553
# 4      2005    140000                ALL       551        NaN       565
#
# [5 rows x 6 columns]

# %%
sats_all = sats[sats['SAT_STU_GROUP_CODE'] == "ALL"] 
#ignore the demographic breakdowns for now
sats_all[:5]
# Out:
#    REC_YEAR  ORG_CODE SAT_STU_GROUP_CODE  SAT_READ  SAT_WRITE  SAT_MATH
# 0      2005     50000                ALL       487        NaN       499
# 1      2005     70000                ALL       545        NaN       529
# 2      2005     90000                ALL       558        NaN       585
# 3      2005    100000                ALL       541        NaN       553
# 4      2005    140000                ALL       551        NaN       565
#
# [5 rows x 6 columns]

# %%
sats_all_2005 = sats_all[sats_all['REC_YEAR'] == 2005]
sats_all_2005[:5]
# Out:
#    REC_YEAR  ORG_CODE SAT_STU_GROUP_CODE  SAT_READ  SAT_WRITE  SAT_MATH
# 0      2005     50000                ALL       487        NaN       499
# 1      2005     70000                ALL       545        NaN       529
# 2      2005     90000                ALL       558        NaN       585
# 3      2005    100000                ALL       541        NaN       553
# 4      2005    140000                ALL       551        NaN       565
#
# [5 rows x 6 columns]

# %%
def get_values(frame, column_name, dist_column_name="ORG_CODE"):
    d = {}
    
    for info in districts_info:
        geoid = int(info['GEOID'])
        
        try:
            org_code = get_org_code(geoid)
            filtered = frame[frame[dist_column_name] == org_code]
        
            if filtered.shape[0] == 1:
                value = filtered[column_name].values[0]
                d[geoid] = value
            else:
                #print filtered.shape
                d[geoid] = 0
        except Exception as ex:
            #print ex
            d[geoid] = 0
            
    return d

values = get_values(sats_all_2005, 'SAT_MATH')
list(values.iteritems())[:20]
# Out:
# [(2506240, 571.0),
#  (2505730, 550.0),
#  (2505220, 542.0),
#  (2525014, 0),
#  (2512390, 483.0),
#  (2504200, 528.0),
#  (2505740, 532.0),
#  (2502670, 543.0),
#  (2502160, 512.0),
#  (2501650, 0),
#  (2508820, 523.0),
#  (2508310, 552.0),
#  (2506780, 498.0),
#  (2510170, 509.0),
#  (2506270, 0),
#  (2512930, 503.0),
#  (2512420, 504.0),
#  (2504230, 476.0),
#  (2511400, 539.0),
#  (2510890, 0)]

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx
cm = plt.get_cmap('gist_rainbow') 
cNorm  = colors.Normalize(vmin=400, vmax=800) #max sat score
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cm)

[scalarMap.to_rgba(400),
 scalarMap.to_rgba(600),
 scalarMap.to_rgba(800)]
# Out:
# [(1.0, 0.0, 0.16, 1.0),
#  (0.0, 1.0, 0.54817625975121254, 1.0),
#  (1.0, 0.0, 0.75, 1.0)]

# %%
def graph_a_thing(shapes, values):
    ax = plt.subplot(111)
    # shapes is the shapefile
    # values is a dict mapping of the GEOIDs in shapes to the heatmap values
    
    for i in range(0,len(shapes)):
        # x and y are empty lists to be populated with the coords of each geometry.
        x = []
        y = []
    
        border, info = shapes[i]
        geoid = int(info['GEOID'])
        value = values[geoid]
    
        for j in range(0,len(border)):
            
            # get x and y coordinates.
            tempx = float(border[j][0]) #x
            tempy = float(border[j][1]) #y
            x.append(tempx)
            y.append(tempy) # Populate the lists  

        # Creates a polygon in matplotlib for each geometry in the shapefile
        if value == 0:
            color = (0.0, 0.0, 0.0, 0.0)
        else:
            color = scalarMap.to_rgba(value)
        plt.fill(x,y, fc=color)

    plt.axis('equal')
    # This sets the x and y axes as equal intervals.
    # NB this script will only work for projected data, for geographical
    # coordinate systems get ready to do some maths  

    #plt.show() # Draws the map!
    plt.axis('off')
    
    b1 = ax.bar([0, 1, 2], [0.2, 0.3, 0.1], color=scalarMap.to_rgba(600), width=0.4, align="edge")
    b2 = ax.bar([0, 1, 2], [0.2, 0.3, 0.1], color=scalarMap.to_rgba(550), width=0.4, align="edge")
    b3 = ax.bar([0, 1, 2], [0.2, 0.3, 0.1], color=scalarMap.to_rgba(500), width=0.4, align="edge")
    b4 = ax.bar([0, 1, 2], [0.2, 0.3, 0.1], color=scalarMap.to_rgba(450), width=0.4, align="edge")

    ax.legend([b1, b2, b3, b4], ["600", "550", "500", "450"])
    ax.set_title("SAT math scores for 2005")
    
    plt.savefig("state.png", figsize=(600,500), dpi=500)
    
graph_a_thing(zip(districts, districts_info), values)
